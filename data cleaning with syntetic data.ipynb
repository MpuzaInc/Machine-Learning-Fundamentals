# %% [markdown]
# # 📘 DATA PREPROCESSING MAJOR STEPS
# ### Developed by: **NIYONSHUTI Yves** | Mpuza Inc.

# %% [markdown]
# ## pandas is a powerful Python library for data manipulation and analysis. It gives you two main data structures:
#
# #### Series – 1-dimensional labeled array
#
# #### DataFrame – 2-dimensional labeled table (like a spreadsheet or SQL table)

# %%
import pandas as pd

# %% [markdown]
# ## Reads a CSV file (Comma-Separated Values) and loads it into a pandas DataFrame.

# %%
dataset = pd.read_csv("data.csv")

# %% [markdown]
# # print(dataset)
# ### Displays the DataFrame as plain text output, similar to how it would look in the terminal.
# ### No styling, no scrollbars.
# ### Use it when you're printing inside loops, functions, or debugging.

# %%
print(dataset)
# Out:
#                  Names Location           Age   Salary         DoB  \
# 0   NZAYISENGA Clement   France            44  72000.0   12/2/2020
# 1       SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020
# 2       SEKABANZA Jean  Germany            30  54000.0           ?
# 3    BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020
# 4        ZAYINABU Sada  Germany            40      NaN  12/10/2020
# 5     SEZIBERA Olivier   France            35  58000.0   12/7/2020
# 6    SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08
# 7       KAMANA Fabrice   France            48  79000.0   12/9/2020
# 8     MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020
# 9      KAMUKAZI Sarah    France           637  67000.0  12/11/2020
# 10       ZAYINABU Sada  Germany            40      NaN  12/10/2020
#
#    Blood types Purchased
# 0      group O        No
# 1      group B       Yes
# 2      group A        No
# 3      group O        No
# 4          G-B       Yes
# ...

# %% [markdown]
# # dataset (just writing the variable name)
# ### Displays a nicely formatted HTML table in Jupyter.
# ### Includes scrollbars for wide data, and styling (like alternating row colors).
# ### Supports interactive features like column sorting (in some environments or extensions).
# ### Best for visual inspection of data.

# %%
dataset
# Out:
#                  Names Location           Age   Salary         DoB  \
# 0   NZAYISENGA Clement   France            44  72000.0   12/2/2020
# 1       SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020
# 2       SEKABANZA Jean  Germany            30  54000.0           ?
# 3    BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020
# 4        ZAYINABU Sada  Germany            40      NaN  12/10/2020
# 5     SEZIBERA Olivier   France            35  58000.0   12/7/2020
# 6    SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08
# 7       KAMANA Fabrice   France            48  79000.0   12/9/2020
# 8     MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020
# 9      KAMUKAZI Sarah    France           637  67000.0  12/11/2020
# 10       ZAYINABU Sada  Germany            40      NaN  12/10/2020
#
#    Blood types Purchased
# 0      group O        No
# 1      group B       Yes
# 2      group A        No
# 3      group O        No
# 4          G-B       Yes
# ...

# %% [markdown]
# ## Returns the first 5 rows of a DataFrame by default. It’s useful to quickly preview your dataset.

# %%
dataset.head()
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020         G-B
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes

# %% [markdown]
# ## You can specify the number of rows to view by passing a specific argument in the head function

# %%
dataset.head(7)
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020         G-B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020         G B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     group B
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        no
# 6        No

# %% [markdown]
# ## Displays the last 5 rows of the DataFrame named dataset. It’s useful for checking the bottom part of your dataset.

# %%
dataset.tail()
# Out:
#                 Names Location  Age   Salary         DoB Blood types Purchased
# 6   SAYINZOGA Gilbert    Spain  NaN  52000.0  2020/16/08     group B        No
# 7      KAMANA Fabrice   France   48  79000.0   12/9/2020         G A       NaN
# 8    MANIRAGUHA Bruno  Germany   50  83000.0  12/10/2020     group B        No
# 9     KAMUKAZI Sarah    France  637  67000.0  12/11/2020     group O        No
# 10      ZAYINABU Sada  Germany   40      NaN  12/10/2020         G-B       Yes

# %% [markdown]
# ## Displays the last 7 rows of the dataset DataFrame.

# %%
dataset.tail(7)
# Out:
#                 Names Location  Age   Salary         DoB Blood types Purchased
# 4       ZAYINABU Sada  Germany   40      NaN  12/10/2020         G-B       Yes
# 5    SEZIBERA Olivier   France   35  58000.0   12/7/2020         G B        no
# 6   SAYINZOGA Gilbert    Spain  NaN  52000.0  2020/16/08     group B        No
# 7      KAMANA Fabrice   France   48  79000.0   12/9/2020         G A       NaN
# 8    MANIRAGUHA Bruno  Germany   50  83000.0  12/10/2020     group B        No
# 9     KAMUKAZI Sarah    France  637  67000.0  12/11/2020     group O        No
# 10      ZAYINABU Sada  Germany   40      NaN  12/10/2020         G-B       Yes

# %% [markdown]
# ## Provides a quick summary of the dataset’s structure, including:
#
# ### 1) Number of rows and columns
#
# ### 2) Column names and data types
#
# ### 3) Number of non-null (non-missing) values
#
# ### 4) Memory usage

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Names        11 non-null     object
#  1   Location     11 non-null     object
#  2   Age          10 non-null     object
#  3   Salary       9 non-null      float64
#  4   DoB          11 non-null     object
#  5   Blood types  11 non-null     object
#  6   Purchased    10 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 748.0+ bytes

# %% [markdown]
# ## Returns a Series showing the data type of each column in the DataFrame.
#
# ### Useful to check if columns are of the correct type (e.g., int, float, object).
#
# ### Helps identify potential issues like numerical values stored as strings.

# %%
dataset.dtypes
# Out:
# Names           object
# Location        object
# Age             object
# Salary         float64
# DoB             object
# Blood types     object
# Purchased       object
# dtype: object

# %% [markdown]
# ## Generates a statistical summary of the numerical columns in your DataFrame. It helps to understand the distribution and spread of your data.
#
# ### Statistic	Meaning
# # ============================
# #### count :	Number of non-null values
# #### mean : 	Mean (average) value
# #### std : 	Standard deviation (spread of values)
# #### min : 	Minimum value
# #### 25% :	25th percentile (lower quartile)
# #### 50% (median) : 	50th percentile (middle value)
# #### 75% : 	75th percentile (upper quartile)
# #### max : 	Maximum value

# %%
dataset.describe()
# Out:
#              Salary
# count      9.000000
# mean   63777.777778
# std    12265.579662
# min    48000.000000
# 25%    54000.000000
# 50%    61000.000000
# 75%    72000.000000
# max    83000.000000

# %% [markdown]
# # 1 REMOVE DUPLICATES
# ## The duplicated() function is used to identify duplicate rows in your DataFrame. It returns a Boolean Series: True for duplicate rows and False for unique rows.

# %%
duplicates = dataset.duplicated()

# %%
duplicates
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# dtype: bool

# %% [markdown]
# ## .sum(): This counts the number of True values, which represent the duplicate rows.

# %%
dataset.duplicated().sum()
# Out:
# 1

# %% [markdown]
# ## dataset[duplicates] filters the DataFrame, keeping only the rows where duplicates is True, i.e., the duplicate rows.
#
# ### This line effectively creates a backup of all duplicate rows in a new variable, duplicateBackup.

# %%
duplicateBackup = dataset[duplicates]

# %%
duplicateBackup
# Out:
#             Names Location Age  Salary         DoB Blood types Purchased
# 10  ZAYINABU Sada  Germany  40     NaN  12/10/2020         G-B       Yes

# %% [markdown]
# ## to_csv() is a method used to write a DataFrame to a CSV file.
#
# ### In this case, duplicateBackup is a DataFrame containing the duplicate rows from your dataset, and you're saving it to a file named "duplicatesBackupRecorded.csv".

# %%
duplicateBackup.to_csv("duplicatesBackupRecorded.csv")

# %% [markdown]
# ## drop_duplicates() is a function in pandas used to remove duplicate rows from a DataFrame.
#
# ### The function returns a new DataFrame with duplicate rows removed, and you can assign it back to the original DataFrame if you want to overwrite it.

# %%
dataset = dataset.drop_duplicates()

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020         G-B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020         G B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     group B
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020         G A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     group B
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        no
# 6        No
# ...

# %%
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 2 HANDLING MISSING VALUES AND INCONSISTANCE

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020         G-B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020         G B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     group B
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020         G A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     group B
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        no
# 6        No
# ...

# %% [markdown]
# ## This line detects missing (null or NaN) values in your dataset.
#
# ### It returns a Boolean DataFrame with the same shape as the original, where each value is:
#
# ### True → if the value is missing (NaN)
#
# ### False → if the value is present

# %%
missingData = dataset.isnull()

# %%
missingData
# Out:
#    Names  Location    Age  Salary    DoB  Blood types  Purchased
# 0  False     False  False   False  False        False      False
# 1  False     False  False   False  False        False      False
# 2  False     False  False   False  False        False      False
# 3  False     False  False   False  False        False      False
# 4  False     False  False    True  False        False      False
# 5  False     False  False   False  False        False      False
# 6  False     False   True   False  False        False      False
# 7  False     False  False   False  False        False       True
# 8  False     False  False   False  False        False      False
# 9  False     False  False   False  False        False      False

# %% [markdown]
# ## This gives a column-wise total of missing values in the dataset.

# %%
missingData.sum()
# Out:
# Names          0
# Location       0
# Age            1
# Salary         1
# DoB            0
# Blood types    0
# Purchased      1
# dtype: int64

# %% [markdown]
# ## What is Imputation?
# ### Imputation means filling in missing values in your dataset instead of removing them. This helps preserve data and avoid losing important patterns during analysis or model training.
#
# ## Use imputation when:
# ### You have missing values that are not too many (e.g., < 30% of a column).
# ### Dropping rows would result in losing too much useful data.
# ### The missing data seems to follow a pattern or is missing at random.
#
# ## When NOT to Impute:
# ### If the missing data has a meaning (e.g., test not taken, product never sold).
# ### If the column is mostly empty (e.g., 80%+ missing), consider dropping it.
#
# ## Imputation Type	Use This When...	Best For	Example
# ### Mean (.mean())	: Data is numerical and normally distributed (no big outliers)
# ### Median (.median())	: Data is numerical but has outliers or is skewed
# ### Mode (.mode())	: Data is categorical (not numbers)

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020         G-B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020         G B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     group B
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020         G A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     group B
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        no
# 6        No
# ...

# %% [markdown]
# ## Checking each column with the missing values, here we start from Purchaised

# %%
dataset[["Purchased"]]
# Out:
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        no
# 6        No
# 7       NaN
# 8        No
# 9        No

# %% [markdown]
# ## As we saw that while a column have categorical values, we impute it using mode, here we use check which value having a mode in the column, means which have bigger frequency, and we found that "No" is a mode with 6 OCCURANCE

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# No     6
# Yes    2
# no     1
# Name: count, dtype: int64

# %% [markdown]
# ## We use this modeImputation as a variable to hold the value of a mode returned from dataset, there is a case sometime where it can return two values that have equal mode, for this case we use "[0]" to specify what will be considered as mode, because we only need one value this will take the mode on index0 whic is first returened element

# %%
modeImputation = dataset["Purchased"].mode()[0]

# %%
modeImputation
# Out:
# 'No'

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020         G-B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020         G B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     group B
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020         G A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     group B
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        no
# 6        No
# ...

# %% [markdown]
# ## here we use numpy as a libiray holding the NaN special value, because missing value is always represented by NaN

# %%
import numpy as np

# %% [markdown]
# ## here we replace the NaN in the Purchased column with modeImputation which is a variable above holding the value of mode., we use inplace as True to make this change happen to our variable dataset directly from temporaly memory.

# %%
dataset["Purchased"].replace(np.nan,modeImputation, inplace = True )
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\1147697934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["Purchased"].replace(np.nan,modeImputation, inplace = True )

# %% [markdown]
# ## Now if we can see the column purchaised, it is clear that the NaN is replaced with the Mode Value returned.

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020         G-B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020         G B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     group B
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020         G A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     group B
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        no
# 6        No
# ...

# %% [markdown]
# ## if we can see well the output of value_count() we see that there are 3 categories because python is case sensitive, it treat "No" capitalized  differently with "no" in lower letter, while those all means the same, for this problem we have to make sure that all the data have the same stlye to mentain consistance of the data

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# No     7
# Yes    2
# no     1
# Name: count, dtype: int64

# %% [markdown]
# ## we take decision to capitalize all the values( means all the starting string should be in uppercase the others in lower case, here the confusion of "no" and "No") will not happen again

# %%
dataset["Purchased"] = dataset["Purchased"].str.capitalize()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\3204209535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["Purchased"] = dataset["Purchased"].str.capitalize()

# %% [markdown]
# ## Now ou see the output that we have only 2 categories means "no" value we had become "No" so that the mix in the same category

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# No     8
# Yes    2
# Name: count, dtype: int64

# %% [markdown]
# ## Our Purchased column is not having missing value and all the value are consistantly styled

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020         G-B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020         G B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     group B
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020         G A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     group B
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# ...

# %% [markdown]
# ## We Continue to another column "Blood types" where we want to check the unique values of it in order to see the occurence of values

# %%
dataset["Blood types"].unique()
# Out:
# array(['group O', 'group B', 'group A', 'G-B', 'G B', 'G A'], dtype=object)

# %% [markdown]
# ## nunique return number of unique values in the column so that we can compare with number of records / observation we have in order to know that there are some that are categoriczed in the together, means sharing the same value

# %%
dataset["Blood types"].nunique()
# Out:
# 6

# %% [markdown]
# ## we use "value_count()" function to check how many unique values we have with respect to the number of records categorized together for each, in order to see what categories have many occurance and the one with low occurance. the target we have here is to detect if there was some typo for the types with lower occurency while users wanted to mean the other category or if there is some inconsistance of the values. for example: "M" and "Male" can be same thing but categorized differently, or "G B" or "G-B" can be a typo while user wanted to write "group B"
#
# ## by experience the categories with lower value occurance sometime have such problem and we give priority the one with higher occurence to harmonize it. for example: "group B" have 3 ocurence so that we give it a priority and other with lower occurancy will change name to harmonize with this.

# %%
dataset["Blood types"].value_counts()
# Out:
# Blood types
# group O    3
# group B    3
# group A    1
# G-B        1
# G B        1
# G A        1
# Name: count, dtype: int64

# %% [markdown]
# ## we replace where there is "G-B" with "group B" now to make consistance

# %%
dataset["Blood types"].replace("G-B","group B", inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\1177519343.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["Blood types"].replace("G-B","group B", inplace = True)

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020     group B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020         G B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     group B
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020         G A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     group B
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# ...

# %%
dataset["Blood types"].replace("G B","group B", inplace = True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\3594875295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["Blood types"].replace("G B","group B", inplace = True)

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020     group B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020     group B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     group B
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020         G A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     group B
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# ...

# %%
dataset["Blood types"] = dataset["Blood types"].replace("G A","group A")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\1166625044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["Blood types"] = dataset["Blood types"].replace("G A","group A")

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020     group B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020     group B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     group B
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020     group A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     group B
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# ...

# %% [markdown]
# ### The SettingWithCopyWarning below appears because we previously removed duplicates from the original DataFrame,
# ### which may have created a view instead of a full copy. Modifying such a view directly can lead to unpredictable behavior.
# ### To solve this, we use .copy() after drop_duplicates() to ensure we're working with a full, independent DataFrame.
# ### Additionally, we use .loc for assignment to make the modification explicit and safe.
#
# ## As the first letter on Purchased capitalize, we may make harmonization to other column to start with capital letter, Lets start with "group A" to become "Group A"

# %%
dataset.loc[:, "Blood types"] = dataset["Blood types"].replace("group A","Group A")

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     Group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020     group B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020     group B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     group B
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020     Group A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     group B
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# ...

# %% [markdown]
# ### IT IS painful to go replace for each value of category, so we may use the previous apploach to use Capitalize the first characters for all records

# %%
dataset.loc[:,"Blood types"] = dataset["Blood types"].str.capitalize()

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     Group o
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     Group b
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     Group a
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     Group o
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020     Group b
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020     Group b
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     Group b
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020     Group a
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     Group b
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     Group o
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# ...

# %% [markdown]
# ## This is a good approach but we may capitalize the first and last letter to make it so very clear and readable. here we use slicing to achieve this and we concatenate all the condition as follow: the first letter on index 0 to be in upper case, the characters in middle should be in lower case and the last character to be in upper case
# ### Capitalizes the first and last letter of each string in the 'Blood types' column.
# ### This is achieved by separately uppercasing the first and last characters,
# ### while keeping the middle part of the string unchanged.
# ### This method uses pandas' vectorized string operations for efficient processing.

# %%
dataset.loc[:,"Blood types"] = dataset["Blood types"].str[0].str.upper() + dataset["Blood types"].str[1:-1].str.lower() + dataset["Blood types"].str[-1].str.upper()

# %% [markdown]
# ## for this column the data are consistant and there is no missing value

# %%
dataset
# Out:
#                 Names Location           Age   Salary         DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0   12/2/2020     Group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0  12/10/2020     Group B
# 2      SEKABANZA Jean  Germany            30  54000.0           ?     Group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0  12/10/2020     Group O
# 4       ZAYINABU Sada  Germany            40      NaN  12/10/2020     Group B
# 5    SEZIBERA Olivier   France            35  58000.0   12/7/2020     Group B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0  2020/16/08     Group B
# 7      KAMANA Fabrice   France            48  79000.0   12/9/2020     Group A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0  12/10/2020     Group B
# 9     KAMUKAZI Sarah    France           637  67000.0  12/11/2020     Group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# ...

# %% [markdown]
# ## we are going to check the unique values of the dates

# %%
dataset["DoB"].unique()
# Out:
# array(['12/2/2020', '12/10/2020', '?', '12/7/2020', '2020/16/08',
#        '12/9/2020', '12/11/2020'], dtype=object)

# %% [markdown]
# ## we observe that a DoB of "12/10/2020" have occurence of " 4 " which can be like mode the others are unique means no person having the same DoB on those dates, and 2020/16/08 have no existing month of 16th while we have another unknown format of date which is a "?"

# %%
dataset["DoB"].value_counts()
# Out:
# DoB
# 12/10/2020    4
# 12/2/2020     1
# ?             1
# 12/7/2020     1
# 2020/16/08    1
# 12/9/2020     1
# 12/11/2020    1
# Name: count, dtype: int64

# %%
# we use dropna parameter to include the NAN to count
dataset["DoB"].value_counts(dropna = False)
# Out:
# DoB
# 12/10/2020    4
# 12/2/2020     1
# ?             1
# 12/7/2020     1
# 2020/16/08    1
# 12/9/2020     1
# 12/11/2020    1
# Name: count, dtype: int64

# %% [markdown]
# # Try to convert all the dates to datetime; errors='coerce' will set invalid ones to NaT (Not A Time)

# %%
dataset["DoB"] = pd.to_datetime(dataset["DoB"], errors = "coerce")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\3611265203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["DoB"] = pd.to_datetime(dataset["DoB"], errors = "coerce")

# %%
dataset["DoB"]
# Out:
# 0   2020-12-02
# 1   2020-12-10
# 2          NaT
# 3   2020-12-10
# 4   2020-12-10
# 5   2020-12-07
# 6          NaT
# 7   2020-12-09
# 8   2020-12-10
# 9   2020-12-11
# Name: DoB, dtype: datetime64[ns]

# %% [markdown]
# ## Now find which values failed to convert as THOSE BECOME NaT

# %%
dataset[dataset["DoB"].isna()]
# Out:
#                Names Location  Age   Salary DoB Blood types Purchased
# 2     SEKABANZA Jean  Germany   30  54000.0 NaT     Group A        No
# 6  SAYINZOGA Gilbert    Spain  NaN  52000.0 NaT     Group B        No

# %%
dataset
# Out:
#                 Names Location           Age   Salary        DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0 2020-12-02     Group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0 2020-12-10     Group B
# 2      SEKABANZA Jean  Germany            30  54000.0        NaT     Group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0 2020-12-10     Group O
# 4       ZAYINABU Sada  Germany            40      NaN 2020-12-10     Group B
# 5    SEZIBERA Olivier   France            35  58000.0 2020-12-07     Group B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0        NaT     Group B
# 7      KAMANA Fabrice   France            48  79000.0 2020-12-09     Group A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0 2020-12-10     Group B
# 9     KAMUKAZI Sarah    France           637  67000.0 2020-12-11     Group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# 7        No
# ...

# %% [markdown]
#  ## You can use any date you want based on business needs and decision from the bosses, we choose "2020-12-01" this because is because all the date having the common pattern of "2020-01" and varie based on days, we took decision to choose a date from when the month start for everyone, based on the decision from business we can even use a mode

# %%
dataset.loc[:,'DoB'] = dataset['DoB'].fillna(pd.Timestamp('2020-12-01'))

# %% [markdown]
# ## Now we have the DoB that are consistant and without any missing values

# %%
dataset
# Out:
#                 Names Location           Age   Salary        DoB Blood types  \
# 0  NZAYISENGA Clement   France            44  72000.0 2020-12-02     Group O
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.0 2020-12-10     Group B
# 2      SEKABANZA Jean  Germany            30  54000.0 2020-12-01     Group A
# 3   BYUKUSENGE Devote    Spain            38  61000.0 2020-12-10     Group O
# 4       ZAYINABU Sada  Germany            40      NaN 2020-12-10     Group B
# 5    SEZIBERA Olivier   France            35  58000.0 2020-12-07     Group B
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.0 2020-12-01     Group B
# 7      KAMANA Fabrice   France            48  79000.0 2020-12-09     Group A
# 8    MANIRAGUHA Bruno  Germany            50  83000.0 2020-12-10     Group B
# 9     KAMUKAZI Sarah    France           637  67000.0 2020-12-11     Group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# 7        No
# ...

# %% [markdown]
# ## we start to clean missing data into a Salary column, we see that it is numerical values and have missing data. we may impute it either using "MEAN" or "MEDIAN".
# ### As we saw, we use mean while the variable data is normally distributed and without outliers. so we need to check them first before deciding if we will use mean else we will use median because it is surviving for outliers

# %%
dataset["Salary"]
# Out:
# 0    72000.0
# 1    48000.0
# 2    54000.0
# 3    61000.0
# 4        NaN
# 5    58000.0
# 6    52000.0
# 7    79000.0
# 8    83000.0
# 9    67000.0
# Name: Salary, dtype: float64

# %% [markdown]
# ## we use samarry statistics to check if the median (50%) is close to  mean, the min and max, if it is close we are sure that our variable is normally distributed and no outliers. as we see a mean of "63777" is close to "62388" and close to min and max

# %%
dataset["Salary"].describe()
# Out:
# count       10.000000
# mean     63777.777778
# std      11564.099406
# min      48000.000000
# 25%      55000.000000
# 50%      62388.888889
# 75%      70750.000000
# max      83000.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ## The KDE (Kernel Density Estimate) curve overlaid on the histogram gives a good visual cue. A bell-shaped curve is a good sign of normality. here this curve showing that it is normaly distributed cz is bell shapped curve

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(dataset['Salary'], kde=True)
plt.title("Histogram with KDE")
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Since p = 0.999 > 0.05, we fail to reject the null hypothesis that the data comes from a normal distribution.
#
# ## Interpretation: The data in Salary is probably normally distributed.

# %%
from scipy.stats import kstest, norm

isNormalDistribution = dataset['Salary'].dropna()
stat, p = kstest((isNormalDistribution - isNormalDistribution.mean()) / isNormalDistribution.std(), 'norm')
print('K-S Test: stat=%.3f, p=%.3f' % (stat, p))

if p > 0.05:
    print("Probably normal")
else:
    print("Probably not normal")
# Out:
# K-S Test: stat=0.106, p=0.999
# Probably normal

# %% [markdown]
# ## we plot this column with boxplot to check if it contain outliers, we luckly see that it has no outliers

# %%
plt.boxplot(x=dataset['Salary'])
plt.title('Boxplot of Salary')
plt.show()

# %% [markdown]
# ## from the above all reason, it is approved that we may impute this salary missing value using "Mean", because it is normally distributed and have no outliers

# %%
dataset.loc[:,"Salary"] = dataset["Salary"].fillna(dataset["Salary"].mean())

# %%
dataset
# Out:
#                 Names Location           Age        Salary        DoB  \
# 0  NZAYISENGA Clement   France            44  72000.000000 2020-12-02
# 1      SIBOMANA Peter    Spain  Twenty seven  48000.000000 2020-12-10
# 2      SEKABANZA Jean  Germany            30  54000.000000 2020-12-01
# 3   BYUKUSENGE Devote    Spain            38  61000.000000 2020-12-10
# 4       ZAYINABU Sada  Germany            40  63777.777778 2020-12-10
# 5    SEZIBERA Olivier   France            35  58000.000000 2020-12-07
# 6   SAYINZOGA Gilbert    Spain           NaN  52000.000000 2020-12-01
# 7      KAMANA Fabrice   France            48  79000.000000 2020-12-09
# 8    MANIRAGUHA Bruno  Germany            50  83000.000000 2020-12-10
# 9     KAMUKAZI Sarah    France           637  67000.000000 2020-12-11
#
#   Blood types Purchased
# 0     Group O        No
# 1     Group B       Yes
# 2     Group A        No
# 3     Group O        No
# 4     Group B       Yes
# 5     Group B        No
# ...

# %% [markdown]
# # lets't we check our Age column, we see that it is numerical and have missing value, means we may impute it with either mean or median, but the problem is that we can find either mean or median because it is having number in letters which is "Twenty Seven"

# %%
dataset["Age"]
# Out:
# 0              44
# 1    Twenty seven
# 2              30
# 3              38
# 4              40
# 5              35
# 6             NaN
# 7              48
# 8              50
# 9             637
# Name: Age, dtype: object

# %%
## for the case  of converting letter numbers into numerical numbers we need to install "word2num" library

# %%
pip install word2num
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## we import "w2n" from Word2numbers

# %%
from word2number import w2n

# %% [markdown]
# ## we use to convert where there is letter numbers and keep the NaN

# %%
dataset.loc[:,"Age"] = dataset["Age"].apply(lambda x: w2n.word_to_num(x) if pd.notnull(x) else x)

# %% [markdown]
# ## now "Twenty seven" becoming a number "27.0" and it changes all the column to floating point numbers because while converting it find a NaN which is a Float by nature.

# %%
dataset
# Out:
#                 Names Location    Age        Salary        DoB Blood types  \
# 0  NZAYISENGA Clement   France   44.0  72000.000000 2020-12-02     Group O
# 1      SIBOMANA Peter    Spain   27.0  48000.000000 2020-12-10     Group B
# 2      SEKABANZA Jean  Germany   30.0  54000.000000 2020-12-01     Group A
# 3   BYUKUSENGE Devote    Spain   38.0  61000.000000 2020-12-10     Group O
# 4       ZAYINABU Sada  Germany   40.0  63777.777778 2020-12-10     Group B
# 5    SEZIBERA Olivier   France   35.0  58000.000000 2020-12-07     Group B
# 6   SAYINZOGA Gilbert    Spain    NaN  52000.000000 2020-12-01     Group B
# 7      KAMANA Fabrice   France   48.0  79000.000000 2020-12-09     Group A
# 8    MANIRAGUHA Bruno  Germany   50.0  83000.000000 2020-12-10     Group B
# 9     KAMUKAZI Sarah    France  637.0  67000.000000 2020-12-11     Group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# 7        No
# 8        No
# ...

# %% [markdown]
# ## The KDE (Kernel Density Estimate) curve overlaid on the histogram gives a good visual cue. A bell-shaped curve is a good sign of normality. here this curve showing that it is NOT normaly distributed cz is NOT A bell shapped curve

# %%
sns.histplot(dataset['Age'], kde=True)
plt.title("Histogram with KDE")
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Names        10 non-null     object
#  1   Location     10 non-null     object
#  2   Age          9 non-null      object
#  3   Salary       10 non-null     float64
#  4   DoB          10 non-null     datetime64[ns]
#  5   Blood types  10 non-null     object
#  6   Purchased    10 non-null     object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 640.0+ bytes

# %% [markdown]
# ## we make out Age column to a numerical number

# %%
dataset.loc[:,'Age'] = pd.to_numeric(dataset['Age'], errors='coerce')

# %% [markdown]
# ## Since p = 0.014 < 0.05, we fail to accept the null hypothesis that the data comes from a normal distribution.
#
# ## Interpretation: The data in Age is probably not normally distributed.

# %%
isNormalDistribution = dataset['Age'].dropna()
stat, p = kstest((isNormalDistribution - isNormalDistribution.mean()) / isNormalDistribution.std(), 'norm')
print('K-S Test: stat=%.3f, p=%.3f' % (stat, p))

if p > 0.05:
    print("Probably normal")
else:
    print("Probably not normal")
# Out:
# K-S Test: stat=0.498, p=0.014
# Probably not normal

# %% [markdown]
# ## this boxplot show us that we have outlier

# %%
sns.boxplot(x=dataset['Age'])
plt.title('Boxplot of Age')
plt.show()

# %% [markdown]
# ## now we are sure to decide that we will use Median that can survive to outliers and to the data that are not normally distributed

# %%
dataset.loc[:,"Age"] = dataset["Age"].fillna(dataset["Age"].median())

# %%
dataset
# Out:
#                 Names Location    Age        Salary        DoB Blood types  \
# 0  NZAYISENGA Clement   France   44.0  72000.000000 2020-12-02     Group O
# 1      SIBOMANA Peter    Spain   27.0  48000.000000 2020-12-10     Group B
# 2      SEKABANZA Jean  Germany   30.0  54000.000000 2020-12-01     Group A
# 3   BYUKUSENGE Devote    Spain   38.0  61000.000000 2020-12-10     Group O
# 4       ZAYINABU Sada  Germany   40.0  63777.777778 2020-12-10     Group B
# 5    SEZIBERA Olivier   France   35.0  58000.000000 2020-12-07     Group B
# 6   SAYINZOGA Gilbert    Spain   40.0  52000.000000 2020-12-01     Group B
# 7      KAMANA Fabrice   France   48.0  79000.000000 2020-12-09     Group A
# 8    MANIRAGUHA Bruno  Germany   50.0  83000.000000 2020-12-10     Group B
# 9     KAMUKAZI Sarah    France  637.0  67000.000000 2020-12-11     Group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# 7        No
# 8        No
# ...

# %% [markdown]
# ## we may convert the Age column from float to int because we represent ages as Discrete values

# %%
dataset["Age"] = dataset["Age"].astype(int)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\2030217844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["Age"] = dataset["Age"].astype(int)

# %%
dataset
# Out:
#                 Names Location  Age        Salary        DoB Blood types  \
# 0  NZAYISENGA Clement   France   44  72000.000000 2020-12-02     Group O
# 1      SIBOMANA Peter    Spain   27  48000.000000 2020-12-10     Group B
# 2      SEKABANZA Jean  Germany   30  54000.000000 2020-12-01     Group A
# 3   BYUKUSENGE Devote    Spain   38  61000.000000 2020-12-10     Group O
# 4       ZAYINABU Sada  Germany   40  63777.777778 2020-12-10     Group B
# 5    SEZIBERA Olivier   France   35  58000.000000 2020-12-07     Group B
# 6   SAYINZOGA Gilbert    Spain   40  52000.000000 2020-12-01     Group B
# 7      KAMANA Fabrice   France   48  79000.000000 2020-12-09     Group A
# 8    MANIRAGUHA Bruno  Germany   50  83000.000000 2020-12-10     Group B
# 9     KAMUKAZI Sarah    France  637  67000.000000 2020-12-11     Group O
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# 7        No
# 8        No
# 9        No

# %% [markdown]
# ## now we may check for the Missing value in whole dataset and happy that there is no missing value remained

# %%
dataset.isna().sum()
# Out:
# Names          0
# Location       0
# Age            0
# Salary         0
# DoB            0
# Blood types    0
# Purchased      0
# dtype: int64

# %% [markdown]
# ## we check the datatypes of each column in our dataset

# %%
dataset.dtypes
# Out:
# Names                  object
# Location               object
# Age                     int32
# Salary                float64
# DoB            datetime64[ns]
# Blood types            object
# Purchased              object
# dtype: object

# %% [markdown]
# ## HANDLING OUTLIERS ON Age Column Using Quantile where we set upper bound and lower bound using statistical approach

# %%
Q1 = dataset["Age"].quantile(0.25)
Q3 = dataset["Age"].quantile(0.75)
IQR = Q3 - Q1
lowerb = Q1 - 1.5*IQR
upperb = Q3 + 1.5*IQR

# %% [markdown]
# ## we need to filter and display the outliers records

# %%
outliers = dataset[(dataset["Age"] < lowerb) | (dataset["Age"] > upperb )]
outliers
# Out:
#              Names Location  Age   Salary        DoB Blood types Purchased
# 9  KAMUKAZI Sarah    France  637  67000.0 2020-12-11     Group O        No

# %% [markdown]
# ## Before removing the outliers we need to make its backup in a file for future references

# %%
outliers.to_csv("backupOfOutliers.csv")

# %% [markdown]
# ## we remove the outliers then

# %%
dataset = dataset[(dataset["Age"] >= lowerb) & (dataset["Age"] <= upperb )].copy()

# %% [markdown]
# ## this is a dataset without outliers

# %%
dataset
# Out:
#                 Names Location  Age        Salary        DoB Blood types  \
# 0  NZAYISENGA Clement   France   44  72000.000000 2020-12-02     Group O
# 1      SIBOMANA Peter    Spain   27  48000.000000 2020-12-10     Group B
# 2      SEKABANZA Jean  Germany   30  54000.000000 2020-12-01     Group A
# 3   BYUKUSENGE Devote    Spain   38  61000.000000 2020-12-10     Group O
# 4       ZAYINABU Sada  Germany   40  63777.777778 2020-12-10     Group B
# 5    SEZIBERA Olivier   France   35  58000.000000 2020-12-07     Group B
# 6   SAYINZOGA Gilbert    Spain   40  52000.000000 2020-12-01     Group B
# 7      KAMANA Fabrice   France   48  79000.000000 2020-12-09     Group A
# 8    MANIRAGUHA Bruno  Germany   50  83000.000000 2020-12-10     Group B
#
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5        No
# 6        No
# 7        No
# 8        No

# %% [markdown]
# ## Now there is no outliers on Age Column

# %%
sns.boxplot(x=dataset['Age'])
plt.title('Boxplot of Age')
plt.show()

# %% [markdown]
# # DATA ENCODING

# %%
dataset["Purchased"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
dataset["Purchased"].value_counts()
# Out:
# Purchased
# No     7
# Yes    2
# Name: count, dtype: int64

# %% [markdown]
# ## we import Label Encoder to encode the categorical variables that are having ORDER

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dataset["Purchased"] = le.fit_transform(dataset["Purchased"])

# %%
dataset
# Out:
#                 Names Location  Age        Salary        DoB Blood types  \
# 0  NZAYISENGA Clement   France   44  72000.000000 2020-12-02     Group O
# 1      SIBOMANA Peter    Spain   27  48000.000000 2020-12-10     Group B
# 2      SEKABANZA Jean  Germany   30  54000.000000 2020-12-01     Group A
# 3   BYUKUSENGE Devote    Spain   38  61000.000000 2020-12-10     Group O
# 4       ZAYINABU Sada  Germany   40  63777.777778 2020-12-10     Group B
# 5    SEZIBERA Olivier   France   35  58000.000000 2020-12-07     Group B
# 6   SAYINZOGA Gilbert    Spain   40  52000.000000 2020-12-01     Group B
# 7      KAMANA Fabrice   France   48  79000.000000 2020-12-09     Group A
# 8    MANIRAGUHA Bruno  Germany   50  83000.000000 2020-12-10     Group B
#
#    Purchased
# 0          0
# 1          1
# 2          0
# 3          0
# 4          1
# 5          0
# 6          0
# 7          0
# 8          0

# %%
dataset["Blood types"] = le.fit_transform(dataset["Blood types"])

# %%
dataset
# Out:
#                 Names Location  Age        Salary        DoB  Blood types  \
# 0  NZAYISENGA Clement   France   44  72000.000000 2020-12-02            2
# 1      SIBOMANA Peter    Spain   27  48000.000000 2020-12-10            1
# 2      SEKABANZA Jean  Germany   30  54000.000000 2020-12-01            0
# 3   BYUKUSENGE Devote    Spain   38  61000.000000 2020-12-10            2
# 4       ZAYINABU Sada  Germany   40  63777.777778 2020-12-10            1
# 5    SEZIBERA Olivier   France   35  58000.000000 2020-12-07            1
# 6   SAYINZOGA Gilbert    Spain   40  52000.000000 2020-12-01            1
# 7      KAMANA Fabrice   France   48  79000.000000 2020-12-09            0
# 8    MANIRAGUHA Bruno  Germany   50  83000.000000 2020-12-10            1
#
#    Purchased
# 0          0
# 1          1
# 2          0
# 3          0
# 4          1
# 5          0
# 6          0
# 7          0
# 8          0

# %%
dataset["Location"].value_counts()
# Out:
# Location
# France     3
# Spain      3
# Germany    3
# Name: count, dtype: int64

# %%
dataset["Location"] = le.fit_transform(dataset["Location"])

# %%
dataset
# Out:
#                 Names  Location  Age        Salary        DoB  Blood types  \
# 0  NZAYISENGA Clement         0   44  72000.000000 2020-12-02            2
# 1      SIBOMANA Peter         2   27  48000.000000 2020-12-10            1
# 2      SEKABANZA Jean         1   30  54000.000000 2020-12-01            0
# 3   BYUKUSENGE Devote         2   38  61000.000000 2020-12-10            2
# 4       ZAYINABU Sada         1   40  63777.777778 2020-12-10            1
# 5    SEZIBERA Olivier         0   35  58000.000000 2020-12-07            1
# 6   SAYINZOGA Gilbert         2   40  52000.000000 2020-12-01            1
# 7      KAMANA Fabrice         0   48  79000.000000 2020-12-09            0
# 8    MANIRAGUHA Bruno         1   50  83000.000000 2020-12-10            1
#
#    Purchased
# 0          0
# 1          1
# 2          0
# 3          0
# 4          1
# 5          0
# 6          0
# 7          0
# 8          0

# %%
dataset["Names"].value_counts()
# Out:
# Names
# NZAYISENGA Clement    1
# SIBOMANA Peter        1
# SEKABANZA Jean        1
# BYUKUSENGE Devote     1
# ZAYINABU Sada         1
# SEZIBERA Olivier      1
# SAYINZOGA Gilbert     1
# KAMANA Fabrice        1
# MANIRAGUHA Bruno      1
# Name: count, dtype: int64

# %%
pip install category_encoders

# %%
from category_encoders import TargetEncoder

# %%
X = dataset["Names"]
y = dataset["Purchased"]

# %%
te = TargetEncoder(cols = ["Names"], smoothing = 0.3)

# %%
dataset["Names"] = te.fit_transform(X, y)

# %%
dataset
# Out:
#       Names  Location  Age        Salary        DoB  Blood types  Purchased
# 0  0.222222         0   44  72000.000000 2020-12-02            2          0
# 1  0.222222         2   27  48000.000000 2020-12-10            1          1
# 2  0.222222         1   30  54000.000000 2020-12-01            0          0
# 3  0.222222         2   38  61000.000000 2020-12-10            2          0
# 4  0.222222         1   40  63777.777778 2020-12-10            1          1
# 5  0.222222         0   35  58000.000000 2020-12-07            1          0
# 6  0.222222         2   40  52000.000000 2020-12-01            1          0
# 7  0.222222         0   48  79000.000000 2020-12-09            0          0
# 8  0.222222         1   50  83000.000000 2020-12-10            1          0

# %%
dataset.dtypes
# Out:
# Names                 float64
# Location                int32
# Age                     int32
# Salary                float64
# DoB            datetime64[ns]
# Blood types             int32
# Purchased               int64
# dtype: object

# %%
dataset["DoB Years"] = dataset["DoB"].dt.year

# %%
dataset["DoB Months"] = dataset["DoB"].dt.month

# %%
dataset["DoB Day"] = dataset["DoB"].dt.day

# %%
dataset["DoB WeekDay"] = dataset["DoB"].dt.weekday

# %%
dataset
# Out:
#       Names  Location  Age        Salary        DoB  Blood types  Purchased  \
# 0  0.222222         0   44  72000.000000 2020-12-02            2          0
# 1  0.222222         2   27  48000.000000 2020-12-10            1          1
# 2  0.222222         1   30  54000.000000 2020-12-01            0          0
# 3  0.222222         2   38  61000.000000 2020-12-10            2          0
# 4  0.222222         1   40  63777.777778 2020-12-10            1          1
# 5  0.222222         0   35  58000.000000 2020-12-07            1          0
# 6  0.222222         2   40  52000.000000 2020-12-01            1          0
# 7  0.222222         0   48  79000.000000 2020-12-09            0          0
# 8  0.222222         1   50  83000.000000 2020-12-10            1          0
#
#    DoB Years  DoB Months  DoB Day  DoB WeekDay
# 0       2020          12        2            2
# 1       2020          12       10            3
# 2       2020          12        1            1
# ...

# %%
dataset.drop(columns = ["DoB"], inplace = True)

# %%
dataset
# Out:
#       Names  Location  Age        Salary  Blood types  Purchased  DoB Years  \
# 0  0.222222         0   44  72000.000000            2          0       2020
# 1  0.222222         2   27  48000.000000            1          1       2020
# 2  0.222222         1   30  54000.000000            0          0       2020
# 3  0.222222         2   38  61000.000000            2          0       2020
# 4  0.222222         1   40  63777.777778            1          1       2020
# 5  0.222222         0   35  58000.000000            1          0       2020
# 6  0.222222         2   40  52000.000000            1          0       2020
# 7  0.222222         0   48  79000.000000            0          0       2020
# 8  0.222222         1   50  83000.000000            1          0       2020
#
#    DoB Months  DoB Day  DoB WeekDay
# 0          12        2            2
# 1          12       10            3
# 2          12        1            1
# 3          12       10            3
# ...

# %%
dataset.dtypes
# Out:
# Names          float64
# Location         int32
# Age              int32
# Salary         float64
# Blood types      int32
# Purchased        int64
# DoB Years        int32
# DoB Months       int32
# DoB Day          int32
# DoB WeekDay      int32
# dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
mms = MinMaxScaler()

# %%
ss = StandardScaler()

# %%
dataset["Salary"] = mms.fit_transform(dataset[["Salary"]])

# %%
dataset
# Out:
#       Names  Location  Age    Salary  Blood types  Purchased  DoB Years  \
# 0  0.222222         0   44  0.685714            2          0       2020
# 1  0.222222         2   27  0.000000            1          1       2020
# 2  0.222222         1   30  0.171429            0          0       2020
# 3  0.222222         2   38  0.371429            2          0       2020
# 4  0.222222         1   40  0.450794            1          1       2020
# 5  0.222222         0   35  0.285714            1          0       2020
# 6  0.222222         2   40  0.114286            1          0       2020
# 7  0.222222         0   48  0.885714            0          0       2020
# 8  0.222222         1   50  1.000000            1          0       2020
#
#    DoB Months  DoB Day  DoB WeekDay
# 0          12        2            2
# 1          12       10            3
# 2          12        1            1
# 3          12       10            3
# 4          12       10            3
# ...

# %%
  dataset["Age"] = ss.fit_transform(dataset[["Age"]])

# %%
dataset
# Out:
#       Names  Location       Age    Salary  Blood types  Purchased  DoB Years  \
# 0  0.222222         0  0.675884  0.685714            2          0       2020
# 1  0.222222         2 -1.674349  0.000000            1          1       2020
# 2  0.222222         1 -1.259602  0.171429            0          0       2020
# 3  0.222222         2 -0.153610  0.371429            2          0       2020
# 4  0.222222         1  0.122888  0.450794            1          1       2020
# 5  0.222222         0 -0.568357  0.285714            1          0       2020
# 6  0.222222         2  0.122888  0.114286            1          0       2020
# 7  0.222222         0  1.228880  0.885714            0          0       2020
# 8  0.222222         1  1.505378  1.000000            1          0       2020
#
#    DoB Months  DoB Day  DoB WeekDay
# 0          12        2            2
# 1          12       10            3
# 2          12        1            1
# 3          12       10            3
# ...

# %%
dataset.dtypes
# Out:
# Names          float64
# Location         int32
# Age            float64
# Salary         float64
# Blood types      int32
# Purchased        int64
# DoB Years        int32
# DoB Months       int32
# DoB Day          int32
# DoB WeekDay      int32
# dtype: object

# %% [markdown]
# ## Why Not Just Keep the Month as 1–12?
# #### If you keep the DoB_month as a plain number (1 for January, 12 for December), a machine learning model will think:
#
# #### December (12) is far away from January (1),
#
# #### And March (3) is closer to December than January is.
#
# ## But that's wrong!
# #### December and January are right next to each other on the calendar. So a simple number does not reflect the true relationship.
#
# #### This is where cyclical encoding comes in.
#
# ## Why Use Sine and Cosine?
# #### Using sin() and cos() helps encode the cyclic pattern on a circle instead of a line.
#
# #### Think of the months placed around a clock (a circle):
#
# #### January (1) = 30°
#
# #### April (4) = 120°
#
# #### July (7) = 210°
#
# #### December (12) = 360° (or back to 0°)
#
# #### This way, December and January are close again, and the model can learn cyclical proximity.

# %%
dobMonthIndex = dataset.columns.get_loc('DoB Months')

# %%
dobMonthIndex
# Out:
# 7

# %%
dataset.insert(dobMonthIndex + 1, 'DoB Month Sin', np.round(np.sin(2 * np.pi * dataset['DoB Months'] / 12), 3))

# %%
dataset.insert(dobMonthIndex + 2, 'DoB Month Cos', np.round(np.cos(2 * np.pi * dataset['DoB Months'] / 12), 3))

# %%
dataset
# Out:
#       Names  Location       Age    Salary  Blood types  Purchased  DoB Years  \
# 0  0.222222         0  0.675884  0.685714            2          0       2020
# 1  0.222222         2 -1.674349  0.000000            1          1       2020
# 2  0.222222         1 -1.259602  0.171429            0          0       2020
# 3  0.222222         2 -0.153610  0.371429            2          0       2020
# 4  0.222222         1  0.122888  0.450794            1          1       2020
# 5  0.222222         0 -0.568357  0.285714            1          0       2020
# 6  0.222222         2  0.122888  0.114286            1          0       2020
# 7  0.222222         0  1.228880  0.885714            0          0       2020
# 8  0.222222         1  1.505378  1.000000            1          0       2020
#
#    DoB Months  DoB Month Sin  DoB Month Cos  DoB Day  DoB WeekDay
# 0          12           -0.0            1.0        2            2
# 1          12           -0.0            1.0       10            3
# ...

# %% [markdown]
# # ORDERING COLUMNS TO PUT PREDICTOR / DEPENDANT VARIABLE AT THE END

# %%
newColumnsArangement = ["Names", 
                        "Location", 
                        "DoB Years", 
                        "DoB Months", 
                        "DoB Month Cos", 
                        "DoB Month Sin", 
                        "DoB Day", 
                        "DoB WeekDay", 
                        "Age", 
                        "Salary", 
                        "Purchased"]

# %%
dataset = dataset[newColumnsArangement]

# %%
dataset
# Out:
#       Names  Location  DoB Years  DoB Months  DoB Month Cos  DoB Month Sin  \
# 0  0.222222         0       2020          12            1.0           -0.0
# 1  0.222222         2       2020          12            1.0           -0.0
# 2  0.222222         1       2020          12            1.0           -0.0
# 3  0.222222         2       2020          12            1.0           -0.0
# 4  0.222222         1       2020          12            1.0           -0.0
# 5  0.222222         0       2020          12            1.0           -0.0
# 6  0.222222         2       2020          12            1.0           -0.0
# 7  0.222222         0       2020          12            1.0           -0.0
# 8  0.222222         1       2020          12            1.0           -0.0
#
#    DoB Day  DoB WeekDay       Age    Salary  Purchased
# 0        2            2  0.675884  0.685714          0
# 1       10            3 -1.674349  0.000000          1
# ...

# %%
dataset.corr()
# Out:
#                Names  Location  DoB Years  DoB Months  DoB Month Cos  \
# Names            NaN       NaN        NaN         NaN            NaN
# Location         NaN  1.000000        NaN         NaN            NaN
# DoB Years        NaN       NaN        NaN         NaN            NaN
# DoB Months       NaN       NaN        NaN         NaN            NaN
# DoB Month Cos    NaN       NaN        NaN         NaN            NaN
# DoB Month Sin    NaN       NaN        NaN         NaN            NaN
# DoB Day          NaN  0.105021        NaN         NaN            NaN
# DoB WeekDay      NaN  0.387298        NaN         NaN            NaN
# Age              NaN -0.413893        NaN         NaN            NaN
# Salary           NaN -0.567576        NaN         NaN            NaN
# Purchased        NaN  0.327327        NaN         NaN            NaN
#
#                DoB Month Sin   DoB Day  DoB WeekDay       Age    Salary  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 8
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Names          9 non-null      float64
#  1   Location       9 non-null      int32
#  2   DoB Years      9 non-null      int32
#  3   DoB Months     9 non-null      int32
#  4   DoB Month Cos  9 non-null      float64
#  5   DoB Month Sin  9 non-null      float64
#  6   DoB Day        9 non-null      int32
#  7   DoB WeekDay    9 non-null      int32
#  8   Age            9 non-null      float64
#  9   Salary         9 non-null      float64
#  10  Purchased      9 non-null      int64
# dtypes: float64(5), int32(5), int64(1)
# memory usage: 684.0 bytes

# %% [markdown]
# ## If a column has constant values or no variance, correlation becomes undefined (NaN). like DOB YEAR AND DOB MONTHS
# ### column has NaN correlation with every other column (including Purchased). here we may take a decision to drop it
# ### If a column is not included in the .corr() matrix, it's not contributing to predictive relationships.

# %%
dataset.drop(columns=['Names'], inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\3963984153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop(columns=['Names'], inplace=True)

# %%
dataset.drop(columns=['DoB Years'], inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\1221115670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop(columns=['DoB Years'], inplace=True)

# %%
dataset.drop(columns=['DoB Months'], inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\2100843654.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop(columns=['DoB Months'], inplace=True)

# %%
dataset.drop(columns=['DoB Month Cos'], inplace=True)
dataset.drop(columns=['DoB Month Sin'], inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\846729313.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop(columns=['DoB Month Cos'], inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_23140\846729313.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.drop(columns=['DoB Month Sin'], inplace=True)

# %%
dataset.corr()
# Out:
#              Location   DoB Day  DoB WeekDay       Age    Salary  Purchased
# Location     1.000000  0.105021     0.387298 -0.413893 -0.567576   0.327327
# DoB Day      0.105021  1.000000     0.650791  0.151477  0.297025   0.458349
# DoB WeekDay  0.387298  0.650791     1.000000  0.218591  0.309378   0.507093
# Age         -0.413893  0.151477     0.218591  1.000000  0.909441  -0.414645
# Salary      -0.567576  0.297025     0.309378  0.909441  1.000000  -0.349776
# Purchased    0.327327  0.458349     0.507093 -0.414645 -0.349776   1.000000

# %% [markdown]
# ## What does a correlation of -0.41 AGE mean?
# ### It’s a moderate negative linear correlation.
#
# ### This implies that as Age increases, the likelihood of Purchased = 1 decreases.
#
# ### So, older individuals are less likely to purchase in your data.

# %% [markdown]
# ## SALARY Weak-to-moderate negative – higher salary surprisingly correlates with lower purchases (may need deeper exploration).

# %% [markdown]
# ## lOCATION Weak positive correlation – location may slightly influence purchase decision.

# %% [markdown]
# ### Developed by: **NIYONSHUTI Yves**
